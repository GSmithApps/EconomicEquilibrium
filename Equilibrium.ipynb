# %%
import numpy as np
import matplotlib.pyplot as plt

small_xs = np.arange(0.01,1,0.01)
big_xs = np.arange(1,10,0.1)
xs = np.concatenate((small_xs,big_xs))

y1s = 1**2 / xs
y2s = 3**2 / xs
y3s = 5**2 / xs
y4s = 7**2 / xs

# plot the utility functions and the endowments
plt.plot(xs,y1s,xs,y2s,xs,y3s,xs,y4s)
plt.plot(.02,1/.02,'o')
plt.plot(3,1/3,'o')
plt.axis([-1,10,0,100])

# generate a list of slopes for the trade quantity limit curves
ms = np.arange(-22500/9,-1/9,1/9)

# generate the trade quantity limit curves for player 1
tangent_xs_1 = -1 * (1/.02 - ms * .02) / ( 2 * ms )
tangent_ys_1 = (1/.02 - ms * .02) / 2
plt.plot(tangent_xs_1,tangent_ys_1)

# generate the trade quantity limit curves for player 2
tangent_xs_2 = -1 * (1/3 - ms * 3) / ( 2 * ms )
tangent_ys_2 = (1/3 - ms * 3) / 2
plt.plot(tangent_xs_2,tangent_ys_2)

plt.show()

# %%
# player 1

xs1 = xs - .02

y11 = y1s - 1/.02
y13 = y2s - 1/.02
y15 = y3s - 1/.02
y17 = y4s - 1/.02

plt.plot(xs1,y11,xs1,y13,xs1,y15,xs1,y17)

#Player 2 is below here

xs2 = xs - 3

y21 = y1s - 1/3
y23 = y2s - 1/3
y25 = y3s - 1/3
y27 = y4s - 1/3

plt.plot(xs2,y21,xs2,y23,xs2,y25,xs2,y27)

plt.axis([-4,10,-50,100])

new_xs_1_shifted = new_xs_1 - 0.02
new_ys_1_shifted = new_ys_1 - 1/.02

plt.plot(new_xs_1_shifted,new_ys_1_shifted)
plt.plot(.02-.02,1/.02-1/.02,'o')


new_xs_2_shifted = new_xs_2 - 3
new_ys_2_shifted = new_ys_2 - 1/3

plt.plot(new_xs_2_shifted,new_ys_2_shifted)
plt.plot(3-3,1/3-1/3,'o')

plt.show()

# %%
# # This is player 1's thing rotated
plt.plot(-xs1,-y11,-xs1,-y12,-xs1,-y13,-xs1,-y15,-xs1,-y17)
#plt.plot(-xs1,-y15,-xs1,-y17)

# # player 2
plt.plot(xs2,y21,xs2,y22,xs2,y23,xs2,y25,xs2,y27)
#plt.plot(xs2,y25,xs2,y27)

plt.plot(-new_xs_1_shifted,-new_ys_1_shifted)
plt.plot(.02-.02,1/.02-1/.02,'o')

plt.plot(new_xs_2_shifted,new_ys_2_shifted)
plt.plot(3-3,1/3-1/3,'o')

plt.axis([-1.6,0,0,26])
plt.show()
